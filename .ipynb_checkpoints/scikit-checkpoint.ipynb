# %%
# %pip install --upgrade scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#      - -------------------------------------- 0.3/7.2 MB ? eta -:--:--
#      -- ------------------------------------- 0.5/7.2 MB 1.1 MB/s eta 0:00:06
#      ---- ----------------------------------- 0.8/7.2 MB 1.6 MB/s eta 0:00:04
#      ---------- ----------------------------- 1.8/7.2 MB 2.4 MB/s eta 0:00:03
#      ----------- ---------------------------- 2.1/7.2 MB 2.5 MB/s eta 0:00:03
#      ----------- ---------------------------- 2.1/7.2 MB 2.5 MB/s eta 0:00:03
#      ----------- ---------------------------- 2.1/7.2 MB 2.5 MB/s eta 0:00:03
#      ----------- ---------------------------- 2.1/7.2 MB 2.5 MB/s eta 0:00:03
# ...

# %%
from sklearn.datasets import load
